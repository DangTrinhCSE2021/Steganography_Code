# %%
import cv2 
import numpy as np

def text_to_bin(text):
    return ''.join(format(ord(x), 'b') for x in text)

def bin_to_text(bin_str):
    chars = []
    for i in range(0, len(bin_str), 7):
        byte = bin_str[i:i+7]
        chars.append(chr(int(byte, 2)))
    return ''.join(chars)

def bin_to_num(bin_num):
    exp = 7
    num = 0
    for bit in bin_num:
        if bit == '1':
            num += (2 ** exp)
        exp -= 1
    return num

def num_to_bin(num):
    bin_num = ""
    while True:
        bin_num += str(num % 2)
        num = int(num / 2)
        if num == 0:
            break
    len_num = len(bin_num)
    for i in range(8 - len_num):
        bin_num += "0"
    return bin_num[::-1]
    

def encode(image, secret, key):
    flat_images = image.flatten()
    flat_images_bin = []
    stego = []
    
    for num in flat_images:
        flat_images_bin.append(num_to_bin(num))
        
    index = 0
    
    for pixel in flat_images_bin:
        new_text = ""
        for i in range(len(pixel)):
            if index &gt;= key:
                break
            if i == 6 or i == 7:
                new_text += secret[index]
                index += 1
            else:
                new_text += pixel[i]
        
        stego.append(new_text)
        if index == key:
            break
    
    stego_img = []
    for each in stego:
        stego_img.append(bin_to_num(each))
        
    return stego_img + flat_images[len(stego):].tolist()

def decode(stego,key):
    flat_stegos = stego.flatten()
    flat_stegos_bin = []
    secret_bin = ""
    
    for stego in flat_stegos:
        flat_stegos_bin.append(bin(stego))
    
    index = 1
    for pixel in flat_stegos_bin:
        secret_bin += pixel[6]
        secret_bin += pixel[7]
        index += 2
        if(index == key): break
    
    return bin_to_text(secret_bin)

img = cv2.imread("Cover/00002.jpg")
secret_text = "This is the most secure document that no one can touch haha"
secret_text_bin = text_to_bin(secret_text)
key = len(secret_text_bin)

stego = np.array(encode(img,secret_text_bin,key))
stego_img = np.reshape(stego, img.shape)
# Convert stego image to uint8 type
stego_img = stego_img.astype(np.uint8)

cv2.imshow("Cover Image", img)
cv2.imshow("Stego Image", stego_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
#   Cell In[9], line 49
#     if index &gt;= key:
#                 ^
# SyntaxError: invalid syntax

# %%
decode(stego_img,key)
# Out:
# 'ThisASg\x03S#\x16\x06n\x7f\x1f$\x0e<\\>^,X\x19\x1bx};9;]\x10:40z noA_]K\x03\x0f\x07:\x07&\x7f.\x1eD\r\x0c\x1d\x0c,\x1dd@ f\x05;!S{g{\x16}9\x02\x11I19\x0b _D;V~}@p\x7f\x0654&4>;i:9~Nrd~9 +\x13;4t(/\x1d^\x153\x0b]|\x07{gZ+\x0fixH\x0b\x11la\x0b\x11L8ss\x0bh\x0e\\R+,j%Qmm\'\x08k\x16g3k.w\x12Ya`>\x7fmbHyDeA8\x0cCx$a\x12/R\x0e}\x19\r\tnQNe\t8i\x18\x106"2\x11h\nNg7\x1dJ\x01#TXa\x06#/e\x1fZfj\x15@(^"f\x14\'*\x7f\'sa\x1c\x12)\x1eI\x16Qon?I\x11I\n{\x7fiCw\x11`UK\x1b\x16Ol\x1ar\x0b\x15#%\x044[w,U\x11\x1b@J\x12ZF,T\x19FjIZm\x0f~\x13S\x16qW\x04\x15Yk;OW}vP\x06\x06\x0bB\x7f#I2\x11 tQ< )\x1f&O\x13;%2\nYNf*O4-\x1550\x0e<6tML